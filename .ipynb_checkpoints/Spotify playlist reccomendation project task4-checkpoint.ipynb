# %% [raw]
# Playlist continuation, a significant aspect of music streaming services like Spotify goes beyond merely providing an extensive music library. This recommender system functionality focuses on suggesting songs based on a user's existing playlist, aiming to create a seamless flow of music. Therefore, understanding the context of a playlist, including its common attributes, is crucial for making relevant music recommendations.
#
# This project emphasises the importance of identifying key attributes within songs in a playlist, as these attributes form the basis of recommendations. Consequently, the primary focus is on comprehending playlist structures within a network. By analysing a song-song co-occurrence network from Spotify's million playlist dataset, the goal is to gain insights into frequently associated songs and identify general patterns. For example, are songs of the same genre often grouped together in playlists? What genres tend to be blended in playlists? Can the "context" of a playlist be defined based on genres alone? (here, context refers to the common properties of the songs which are in the same playlist, which is different form context-based recommendation). The project aims to answer these questions and enhance our understanding of playlist dynamics within the network.

# %% [markdown]
# # Task 4

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from scipy import sparse 

G = pd.read_pickle('bigger_graph.pickle')
G

# %% [raw]
# this task is about performing graph-based recommendation using data retrieved from the Spotify API (you will receive help from the mentor on how to use the API).
#
# a) Choose properties from the Spotify API to enrich node information. Vectorise these attributes. Describe which attributes you chose, what they represent, and why you chose these attributes given the problem.
# b) This time, build a function that takes a song name and performs cosine similarity with the song neighbours to recommend songs. Present your results using two use cases and discuss the implications.
# c) Compare co-occurrence based recommendation with content-based recommendation. Discuss your findings considering use cases and network analyses. What are the advantages and disadvantages of each method? Justify your argument.

# %%
print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
degrees = [G.degree(n) for n in G.nodes()]
print(f"Average degree: {sum(degrees) / len(degrees)}")
print(f"Is the graph connected? {nx.is_connected(G)}")
print(f"Number of connected components: {nx.number_connected_components(G)}")

plt.figure(figsize=(5, 5)) 
pos = nx.spring_layout(G)
nx.draw(G, pos , with_labels=False, node_size=10)
plt.show()
# Out:
# Number of nodes: 2767
# Number of edges: 229384
# Average degree: 165.79978315865557
# Is the graph connected? True
# Number of connected components: 1

# %% [raw]
# the two functions below perform a graph walk to recommend songs. It starts from the input song and then moves to the song that has the highest weight with the input song. Then it moves to the song that has the highest weight with the second song, and so on. It’s like a depth-first search but prioritizing the edges with higher weights.

# %%
def recommend_songs_weighted(graph, input_song, num_recommendations=5):
    recommended_songs = []

    if input_song in graph.nodes:
        current_song = input_song
        visited = set([current_song])
        
        while len(recommended_songs) < num_recommendations:
            neighbors = list(graph[current_song])
            neighbor_weights = [(neighbor, graph.edges[current_song, neighbor]['weight']) for neighbor in neighbors if neighbor not in visited]
            
            if not neighbor_weights:
                break
            
            # Sort neighbors by edge weights in descending order
            neighbor_weights.sort(key=lambda x: x[1], reverse=True)
            
            next_song = neighbor_weights[0][0]
            recommended_songs.append((next_song, neighbor_weights[0][1]))
            visited.add(next_song)
            current_song = next_song
        
        return recommended_songs
    else:
        print("Input song not found in the graph.")
        return None


input_song = "spotify:track:6yHkPtl6UQ7RjtJLBPzbJw"  
num_recommendations = 5 
recommended_songs_weighted = recommend_songs_weighted(G, input_song, num_recommendations)
print("Recommended songs:")
for song in recommended_songs_weighted:
    print(song)
# Out:
# Recommended songs:
# ('spotify:track:0dA2Mk56wEzDgegdC6R17g', 3)
# ('spotify:track:0CcQNd8CINkwQfe1RDtGV6', 5)
# ('spotify:track:152lZdxL1OR0ZMW6KquMif', 4)
# ('spotify:track:3kxfsdsCpFgN412fpnW85Y', 8)
# ('spotify:track:7hDc8b7IXETo14hHIHdnhd', 6)

# %%
import heapq
def recommend_songs(graph, start_song, num_recommendations):
    if start_song not in graph:
        return "The song is not in the graph."

    recommended_songs = []
    song_scores = []

    # Add the start song's neighbors to the heap with their edge weight as the score
    for neighbor in graph[start_song]:
        heapq.heappush(song_scores, (-graph[start_song][neighbor]['weight'], neighbor))

    # While we don't have enough recommendations and the heap is not empty
    while len(recommended_songs) < num_recommendations and song_scores:
        # Get the song with the highest score
        score, song = heapq.heappop(song_scores)

        # Add the song and its score to the list of recommended songs
        recommended_songs.append((song, -score))

        # Add the song's neighbors to the heap with their edge weight as the score
        for neighbor in graph[song]:
            if neighbor not in [song for song, _ in recommended_songs]:
                heapq.heappush(song_scores, (-graph[song][neighbor]['weight'], neighbor))

    return recommended_songs

start_song = "spotify:track:6yHkPtl6UQ7RjtJLBPzbJw"  
num_recommendations = 5 
recommended_songs = recommend_songs(G, start_song, num_recommendations)

print("Recommended songs:")
for song, score in recommended_songs:
    print(f"{song} (score: {score})")
# Out:
# Recommended songs:
# spotify:track:0dA2Mk56wEzDgegdC6R17g (score: 3)
# spotify:track:0CcQNd8CINkwQfe1RDtGV6 (score: 5)
# spotify:track:7qiZfU4dY1lWllzX7mPBI3 (score: 5)
# spotify:track:152lZdxL1OR0ZMW6KquMif (score: 4)
# spotify:track:3kxfsdsCpFgN412fpnW85Y (score: 8)

# %% [raw]
# Both approaches can be valid depending on what you want to achieve. If you want to recommend songs that are most directly related to the input song, your function is the way to go. But if you want to explore the graph more and find songs that might be indirectly related to the input song, the function I provided might be more suitable.

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import time
import pandas as pd

SPOTIPY_CLIENT_ID = '2c79005a25ff450fa2c58921fbfe370f'
SPOTIPY_CLIENT_SECRET = 'e6576447735343e28e391f30a16a9204'
SPOTIPY_REDIRECT_URI = 'http://localhost:3000'

# Define the scope of access
scope = "user-read-private"

# an instance of SpotifyOAuth
oauth = SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID,
                     client_secret=SPOTIPY_CLIENT_SECRET,
                     redirect_uri=SPOTIPY_REDIRECT_URI,
                     scope=scope)

# an instance of Spotipy with the OAuth handler
sp = spotipy.Spotify(auth_manager=oauth)

G = pd.read_pickle('bigger_graph.pickle')

#the nodes in the graph G are Spotify track IDs
for node in G.nodes():
    # Getting track information from Spotify API
    track_info = sp.track(node)
    audio_features = sp.audio_features(node)[0]

    properties = {
        'name': track_info['name'],
        'popularity': track_info['popularity'],
        'duration_ms': track_info['duration_ms'],
        'danceability': audio_features['danceability'],
        'energy': audio_features['energy'],
        'key': audio_features['key'],
        'loudness': audio_features['loudness'],
        'mode': audio_features['mode'],
        'speechiness': audio_features['speechiness'],
        'acousticness': audio_features['acousticness'],
        'instrumentalness': audio_features['instrumentalness'],
        'liveness': audio_features['liveness'],
        'valence': audio_features['valence'],
        'tempo': audio_features['tempo']
    }
    
    # Add these properties to the node in the graph
    G.nodes[node]['properties'] = properties

    time.sleep(0.1)
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 429 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
# ...

# %% [raw]
# The error we keep seeing is a 429 error, which means we have sent too many requests in a given amount of time. Spotify API has rate limits to prevent abuse and ensure a fair usage policy.
#
# We can also use a cache to store the results of our API calls. This way, if we need to retrieve the same information again,we can get it from the cache instead of making another API call
