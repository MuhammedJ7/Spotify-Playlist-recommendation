# %% [raw]
# Playlist continuation, a significant aspect of music streaming services like Spotify goes beyond merely providing an extensive music library. This recommender system functionality focuses on suggesting songs based on a user's existing playlist, aiming to create a seamless flow of music. Therefore, understanding the context of a playlist, including its common attributes, is crucial for making relevant music recommendations.
#
# This project emphasises the importance of identifying key attributes within songs in a playlist, as these attributes form the basis of recommendations. Consequently, the primary focus is on comprehending playlist structures within a network. By analysing a song-song co-occurrence network from Spotify's million playlist dataset, the goal is to gain insights into frequently associated songs and identify general patterns. For example, are songs of the same genre often grouped together in playlists? What genres tend to be blended in playlists? Can the "context" of a playlist be defined based on genres alone? (here, context refers to the common properties of the songs which are in the same playlist, which is different form context-based recommendation). The project aims to answer these questions and enhance our understanding of playlist dynamics within the network.

# %% [markdown]
# # Task 3

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from scipy import sparse 

G = pd.read_pickle('small_graph.pickle')
G

# %% [raw]
# Each node in the small_graph graph represents a song, there are 537 nodes thus 537 songs
# The edges/links show the co-occurrence of two songs appearing in the same playlist
# The links have two properties : weight and common_playlists. The weight is the number of playlists that they are both in and the common_playlists is the list of playlist IDs where the two songs/nodes are in
#
# In this task, i will implement a graph recommendation algorithm based on co-occurrence.
#
# a) Build a function that takes an input song name, and performs a graph-walk based on the edge weights to recommend songs.

# %%
print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
degrees = [G.degree(n) for n in G.nodes()]
print(f"Average degree: {sum(degrees) / len(degrees)}")
print(f"Is the graph connected? {nx.is_connected(G)}")
print(f"Number of connected components: {nx.number_connected_components(G)}")

plt.figure(figsize=(5, 5)) 
pos = nx.spring_layout(G)
nx.draw(G, pos , with_labels=False, node_size=10)
plt.show()
# Out:
# Number of nodes: 537
# Number of edges: 7715
# Average degree: 28.733705772811916
# Is the graph connected? True
# Number of connected components: 1

# %%
#a dictionary of all the nodes and their respective degrees 
#degrees is a dictionary that you can use to look up the degree of any node in the graph. 
#For example, degrees[node] will give you the degree of node
degrees = dict(G.degree())

degree_centrality = nx.degree_centrality(G)
closeness_centrality = nx.closeness_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)
eigenvector_centrality = nx.eigenvector_centrality(G)

for node in list(G.nodes())[:1]:
    print(f"Node: {node}")
    print(f"Degree: {degrees[node]}")
    print(f"Degree Centrality: {degree_centrality[node]}")
    print(f"Closeness Centrality: {closeness_centrality[node]}")
    print(f"Betweenness Centrality: {betweenness_centrality[node]}")
    print(f"Eigenvector Centrality: {eigenvector_centrality[node]}")
    print()
# Out:
# Node: spotify:track:00qOE7OjRl0BpYiCiweZB2
# Degree: 19
# Degree Centrality: 0.03544776119402985
# Closeness Centrality: 0.22964867180805484
# Betweenness Centrality: 0.0
# Eigenvector Centrality: 4.084216235227726e-06

# %%
fig, axs = plt.subplots(2,2, figsize=(10, 10))

axs[0, 0].hist(degree_centrality.values(), bins=20, color='b', alpha=0.7)
axs[0, 0].set_title('Degree Centrality')
axs[0, 0].set_xlabel('Degree Centrality Values')
axs[0, 0].set_ylabel('Frequency')

axs[0, 1].hist(closeness_centrality.values(), bins=20, color='r', alpha=0.7)
axs[0, 1].set_title('Closeness Centrality')
axs[0, 1].set_xlabel('Closeness Centrality Values')
axs[0, 1].set_ylabel('Frequency')

axs[1, 0].hist(betweenness_centrality.values(), bins=20, color='g', alpha=0.7)
axs[1, 0].set_title('Betweenness Centrality')
axs[1, 0].set_xlabel('Betweenness Centrality Values')
axs[1, 0].set_ylabel('Frequency')

axs[1, 1].hist(eigenvector_centrality.values(), bins=20, color='y', alpha=0.7)
axs[1, 1].set_title('Eigenvector Centrality')
axs[1, 1].set_xlabel('Eigenvector Centrality Values')
axs[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [raw]
# Context of the centrality metrics in this case :
# Degree : This is the average number of direct connections each song has.A higher degree centrality means a song appears in more playlists with other songs
#
# Closeness : This measures how close a song is to all other songs in the network, based on the shortest paths between them. A higher closeness centrality means a song tends to appear in playlists with a wider variety of other songs
#
# Betweenness : This measures the extent to which a song lies on paths between other songs. A higher betweenness centrality means a song is more likely to connect disparate parts of the network, i.e., it appears in playlists that bring together songs that otherwise don’t co-occur much.
#
# In the context of playlist analysis, betweenness centrality can indicate how versatile or diverse a song is in terms of being compatible with different songs or genres. A song with high betweenness centrality can be added to many playlists with different contexts, while a song with low betweenness centrality can only fit in a few playlists with similar contexts.
#
# Eigenvector Centrality: This measures the influence of a song, taking into account the number and quality of connections. A song has a high eigenvector centrality if it is connected to many songs that are themselves well connected.A song with high eigenvector centrality would be frequently added to playlists that contain other popular or relevant songs.
# Eigenvector centrality can capture the popularity and compatibility of a song in the music streaming platform.
#
# These measures can help us understand the structure of the network and identify important songs within it. For example, songs with high degree and eigenvector centrality might be considered “popular” or “influential” within the network of playlists.
